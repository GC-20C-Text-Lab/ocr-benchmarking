# %% [markdown]
# # JSON accuracy example

# %% [markdown]
# ### Create copies of ground truth

# %%
from json_accuracy import *
from pathlib import Path
import pandas as pd
root_dir = Path.cwd().parent.parent

gt_df_raw = load_json_safely(root_dir / "data" / "ground-truth" / "json" / "gt_kbaa-p100.json")
gt_df = filter_expected_columns(gt_df_raw)

pred_df = gt_df.copy()

gt_df_original = gt_df.copy()

pred_df_cell_mismatch = pred_df.copy()
pred_df_cell_mismatch.loc[2, "description"] = "no description"
pred_df_cell_mismatch.loc[3, "description"] = "Civil War soldier and governor of Illinoi." # Very similar, should pass Jaro-Winkler
pred_df_cell_mismatch.loc[3, "publishyear"] = 9999

pred_df_top_row_mismatch = pred_df.copy()
pred_df_top_row_mismatch = pred_df_top_row_mismatch.drop(0, axis="index").reset_index(drop=True)

pred_df_bottom_row_mismatch = pred_df.copy()
pred_df_bottom_row_mismatch = pred_df_bottom_row_mismatch.drop(19, axis="index").reset_index(drop=True)

pred_df_two_rows_mismatch = pred_df.copy()
pred_df_two_rows_mismatch = pred_df_two_rows_mismatch.drop([0, 1], axis="index").reset_index(drop=True)

pred_df_removed_col = pred_df.copy()
pred_df_removed_col = pred_df_removed_col.drop(columns=["index", "description"]).reset_index(drop=True)

# %% [markdown]
# - Notice that before running the `filter_expected_columns`, empty values are populated as `NaN` and all values have correct capitalization.

# %%
gt_df_raw
# Out:
#      lastname           firstname  \
# 0       Field           Joseph E.
# 1       Field             Richard
# 2       Field     Stephen Johnson
# 3       Fifer       Joseph Wilson
# 4       Finch          Edwin Ward
# 5       Finck    Henry Theophilos
# 6     Finerty      John Frederick
# 7      Finley       James Bradley
# 8      Finley       James Bradley
# 9        Finn       Francis James
# 10     Finney   Charles Grandison
# 11     Finney   Charles Grandison
# 12     Finney  John Miller Turpin
# 13  Firestone           Harvey S.
# 14    Fischer   Augusta Catherine
# 15     Fisher               Clara
# 16     Fisher      Daniel Webster
# 17     Fisher           Elizabeth
# 18     Fisher        George Adams
# 19     Fisher           Hugh Dunn
#
#                                                 title               city  \
# 0                             Three years in Texas...             Boston
# 1                                      Richard Field.     Lexington, Mo.
# 2   Personal reminiscences of early days in Califo...     San Francisco?
# 3       "Private Joe" Fifer. Memories of war & peace.  Bloomington, Ill.
# 4   The frontier, army and professional life of Ed...               N.Y.
# 5           My adventures in the golden age of music.               N.Y.
# 6   War-path and bivouac... the Big Horn and Yello...            Chicago
# 7   Autobiography of Rev. James B. Finley; or, pio...              Cinc.
# 8                           Life among the Indians...              Cinc.
# 9   Father Finn, S.J.; the story of his life told ...               N.Y.
# 10   Charles G. Finney. An autobiography. Popular ed.       London, N.Y.
# 11                        The inner and outer life...             London
# 12                                  A surgeon's life.               N.Y.
# 13                                  Men and rubber...        Garden City
# 14                     Searchlight; an autobiography.            Seattle
# 15                                                NaN                NaN
# 16                                    A human life...               N.Y.
# 17  Memoirs, of Mrs. Elizabeth Fisher, of the city...               N.Y.
# 18  The Yankee conscript, or eighteen months in Di...             Phila.
# 19                   The gun and the gospel...4th ed.        Kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                       Abel Tompkins       1836.0       47.0
# 1                                                 NaN       1930.0       38.0
# 2                                                 NaN       1880.0      248.0
# 3                                  Pantagraph pr. co.       1936.0      104.0
# 4                 Press of Simmonds, Manning & Dawson       1909.0      119.0
# 5                                     Funk & Wagnalls       1926.0      462.0
# 6                                                 NaN       1890.0      460.0
# 7   pr. at the Methodist book concern, for the author       1853.0      455.0
# 8                                  Hitchcock & Walden       1868.0      507.0
# 9                                      Benziger bros.       1929.0      236.0
# 10                 The Slavation army book department       1903.0      401.0
# 11                                    S. W. Partridge       1882.0       32.0
# 12                                             Putnam       1940.0      400.0
# 13                                    Doubleday, Page       1926.0      279.0
# 14                                                NaN       1937.0      233.0
# 15                                                NaN          NaN        NaN
# 16                                             Revell       1909.0      325.0
# 17                                                NaN       1810.0       48.0
# 18                                    J. W. Daughaday       1864.0      251.0
# 19                                    Hudson-Kimberly       1902.0      347.0
#
#    library                                        description   index  \
# 0      DLC            His experiences in the War with Mexico.  1920.0
# 1      MoK  Missouri lawyer and judge tells also of his yo...  1921.0
# 2      WHi    By a judge and member of the state legislature.  1922.0
# 3      WHi        Civil War soldier and governor of Illinois.  1923.0
# 4      DLC  A New York physician tells of his boyhood on a...  1924.0
# 5       WU                                      Music critic.  1925.0
# 6      DLC  Newspaper correspondent with Crook, 1866-67, i...  1926.0
# 7      WHi                    Methodist in the old Northwest.  1927.0
# 8      WHi          An enlarged version of the previous item.  1928.0
# 9       NN  Teacher in St. Louis and Cincinnati. A pioneer...  1929.0
# 10     WHi  Presbyterian, later Congregational, clergyman ...  1930.0
# 11     WHi  The author left the Presbyterian church to bec...  1931.0
# 12      WU                     In Massachusetts and Maryland.  1932.0
# 13      WU                   Manufacturer of rubber products.  1933.0
# 14      NN  The story of the causes leading to the author'...  1934.0
# 15     NaN                   See Maeder, Mrs. Clara (Fisher).     NaN
# 16      PU  Presbyterian clergyman who was also president ...  1935.0
# 17     DLC                               By an American Tory.  1936.0
# 18      WU                                By a Union soldier.  1937.0
# 19     WHi  Methodist clergyman in Kansas, Nebraska, Utah,...     NaN
#
#     birthyear  deathyear maidenname
# 0         NaN        NaN        NaN
# 1      1843.0        NaN        NaN
# 2      1816.0     1899.0        NaN
# 3      1840.0        NaN        NaN
# 4      1831.0        NaN        NaN
# 5      1854.0     1926.0        NaN
# 6      1846.0     1908.0        NaN
# 7      1781.0     1856.0        NaN
# 8      1781.0     1856.0        NaN
# 9      1859.0     1928.0        NaN
# 10     1792.0     1875.0        NaN
# 11        NaN     1875.0        NaN
# 12     1863.0        NaN        NaN
# 13        NaN        NaN        NaN
# 14     1891.0        NaN        NaN
# 15        NaN        NaN        NaN
# 16     1838.0     1913.0        NaN
# 17     1759.0        NaN      Munro
# 18     1835.0        NaN        NaN
# 19     1824.0        NaN        NaN

# %% [markdown]
# - After running the `filter_expected_columns`:
#   - empty values are converted to the specified default values per column:
#     - "" (empty string) for strings
#     - 0 for numbers
#   - non-existent columns are added with default values
#   - everything is lower-case

# %%
gt_df
# Out:
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0       field           joseph e.                   0.0        0.0
# 1       field             richard                1843.0        0.0
# 2       field     stephen johnson                1816.0     1899.0
# 3       fifer       joseph wilson                1840.0        0.0
# 4       finch          edwin ward                1831.0        0.0
# 5       finck    henry theophilos                1854.0     1926.0
# 6     finerty      john frederick                1846.0     1908.0
# 7      finley       james bradley                1781.0     1856.0
# 8      finley       james bradley                1781.0     1856.0
# 9        finn       francis james                1859.0     1928.0
# 10     finney   charles grandison                1792.0     1875.0
# 11     finney   charles grandison                   0.0     1875.0
# 12     finney  john miller turpin                1863.0        0.0
# 13  firestone           harvey s.                   0.0        0.0
# 14    fischer   augusta catherine                1891.0        0.0
# 15     fisher               clara                   0.0        0.0
# 16     fisher      daniel webster                1838.0     1913.0
# 17     fisher           elizabeth      munro     1759.0        0.0
# 18     fisher        george adams                1835.0        0.0
# 19     fisher           hugh dunn                1824.0        0.0
#
#                                                 title               city  \
# 0                             three years in texas...             boston
# 1                                      richard field.     lexington, mo.
# 2   personal reminiscences of early days in califo...     san francisco?
# 3       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4   the frontier, army and professional life of ed...               n.y.
# 5           my adventures in the golden age of music.               n.y.
# 6   war-path and bivouac... the big horn and yello...            chicago
# 7   autobiography of rev. james b. finley; or, pio...              cinc.
# 8                           life among the indians...              cinc.
# 9   father finn, s.j.; the story of his life told ...               n.y.
# 10   charles g. finney. an autobiography. popular ed.       london, n.y.
# 11                        the inner and outer life...             london
# 12                                  a surgeon's life.               n.y.
# 13                                  men and rubber...        garden city
# 14                     searchlight; an autobiography.            seattle
# 15
# 16                                    a human life...               n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 18  the yankee conscript, or eighteen months in di...             phila.
# 19                   the gun and the gospel...4th ed.        kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                       abel tompkins       1836.0       47.0
# 1                                                           1930.0       38.0
# 2                                                           1880.0      248.0
# 3                                  pantagraph pr. co.       1936.0      104.0
# 4                 press of simmonds, manning & dawson       1909.0      119.0
# 5                                     funk & wagnalls       1926.0      462.0
# 6                                                           1890.0      460.0
# 7   pr. at the methodist book concern, for the author       1853.0      455.0
# 8                                  hitchcock & walden       1868.0      507.0
# 9                                      benziger bros.       1929.0      236.0
# 10                 the slavation army book department       1903.0      401.0
# 11                                    s. w. partridge       1882.0       32.0
# 12                                             putnam       1940.0      400.0
# 13                                    doubleday, page       1926.0      279.0
# 14                                                          1937.0      233.0
# 15                                                             0.0        0.0
# 16                                             revell       1909.0      325.0
# 17                                                          1810.0       48.0
# 18                                    j. w. daughaday       1864.0      251.0
# 19                                    hudson-kimberly       1902.0      347.0
#
#    library                                        description   index
# 0      dlc            his experiences in the war with mexico.  1920.0
# 1      mok  missouri lawyer and judge tells also of his yo...  1921.0
# 2      whi    by a judge and member of the state legislature.  1922.0
# 3      whi        civil war soldier and governor of illinois.  1923.0
# 4      dlc  a new york physician tells of his boyhood on a...  1924.0
# 5       wu                                      music critic.  1925.0
# 6      dlc  newspaper correspondent with crook, 1866-67, i...  1926.0
# 7      whi                    methodist in the old northwest.  1927.0
# 8      whi          an enlarged version of the previous item.  1928.0
# 9       nn  teacher in st. louis and cincinnati. a pioneer...  1929.0
# 10     whi  presbyterian, later congregational, clergyman ...  1930.0
# 11     whi  the author left the presbyterian church to bec...  1931.0
# 12      wu                     in massachusetts and maryland.  1932.0
# 13      wu                   manufacturer of rubber products.  1933.0
# 14      nn  the story of the causes leading to the author'...  1934.0
# 15                           see maeder, mrs. clara (fisher).     0.0
# 16      pu  presbyterian clergyman who was also president ...  1935.0
# 17     dlc                               by an american tory.  1936.0
# 18      wu                                by a union soldier.  1937.0
# 19     whi  methodist clergyman in kansas, nebraska, utah,...     0.0

# %%
pred_df
# Out:
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0       field           joseph e.                   0.0        0.0
# 1       field             richard                1843.0        0.0
# 2       field     stephen johnson                1816.0     1899.0
# 3       fifer       joseph wilson                1840.0        0.0
# 4       finch          edwin ward                1831.0        0.0
# 5       finck    henry theophilos                1854.0     1926.0
# 6     finerty      john frederick                1846.0     1908.0
# 7      finley       james bradley                1781.0     1856.0
# 8      finley       james bradley                1781.0     1856.0
# 9        finn       francis james                1859.0     1928.0
# 10     finney   charles grandison                1792.0     1875.0
# 11     finney   charles grandison                   0.0     1875.0
# 12     finney  john miller turpin                1863.0        0.0
# 13  firestone           harvey s.                   0.0        0.0
# 14    fischer   augusta catherine                1891.0        0.0
# 15     fisher               clara                   0.0        0.0
# 16     fisher      daniel webster                1838.0     1913.0
# 17     fisher           elizabeth      munro     1759.0        0.0
# 18     fisher        george adams                1835.0        0.0
# 19     fisher           hugh dunn                1824.0        0.0
#
#                                                 title               city  \
# 0                             three years in texas...             boston
# 1                                      richard field.     lexington, mo.
# 2   personal reminiscences of early days in califo...     san francisco?
# 3       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4   the frontier, army and professional life of ed...               n.y.
# 5           my adventures in the golden age of music.               n.y.
# 6   war-path and bivouac... the big horn and yello...            chicago
# 7   autobiography of rev. james b. finley; or, pio...              cinc.
# 8                           life among the indians...              cinc.
# 9   father finn, s.j.; the story of his life told ...               n.y.
# 10   charles g. finney. an autobiography. popular ed.       london, n.y.
# 11                        the inner and outer life...             london
# 12                                  a surgeon's life.               n.y.
# 13                                  men and rubber...        garden city
# 14                     searchlight; an autobiography.            seattle
# 15
# 16                                    a human life...               n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 18  the yankee conscript, or eighteen months in di...             phila.
# 19                   the gun and the gospel...4th ed.        kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                       abel tompkins       1836.0       47.0
# 1                                                           1930.0       38.0
# 2                                                           1880.0      248.0
# 3                                  pantagraph pr. co.       1936.0      104.0
# 4                 press of simmonds, manning & dawson       1909.0      119.0
# 5                                     funk & wagnalls       1926.0      462.0
# 6                                                           1890.0      460.0
# 7   pr. at the methodist book concern, for the author       1853.0      455.0
# 8                                  hitchcock & walden       1868.0      507.0
# 9                                      benziger bros.       1929.0      236.0
# 10                 the slavation army book department       1903.0      401.0
# 11                                    s. w. partridge       1882.0       32.0
# 12                                             putnam       1940.0      400.0
# 13                                    doubleday, page       1926.0      279.0
# 14                                                          1937.0      233.0
# 15                                                             0.0        0.0
# 16                                             revell       1909.0      325.0
# 17                                                          1810.0       48.0
# 18                                    j. w. daughaday       1864.0      251.0
# 19                                    hudson-kimberly       1902.0      347.0
#
#    library                                        description   index
# 0      dlc            his experiences in the war with mexico.  1920.0
# 1      mok  missouri lawyer and judge tells also of his yo...  1921.0
# 2      whi    by a judge and member of the state legislature.  1922.0
# 3      whi        civil war soldier and governor of illinois.  1923.0
# 4      dlc  a new york physician tells of his boyhood on a...  1924.0
# 5       wu                                      music critic.  1925.0
# 6      dlc  newspaper correspondent with crook, 1866-67, i...  1926.0
# 7      whi                    methodist in the old northwest.  1927.0
# 8      whi          an enlarged version of the previous item.  1928.0
# 9       nn  teacher in st. louis and cincinnati. a pioneer...  1929.0
# 10     whi  presbyterian, later congregational, clergyman ...  1930.0
# 11     whi  the author left the presbyterian church to bec...  1931.0
# 12      wu                     in massachusetts and maryland.  1932.0
# 13      wu                   manufacturer of rubber products.  1933.0
# 14      nn  the story of the causes leading to the author'...  1934.0
# 15                           see maeder, mrs. clara (fisher).     0.0
# 16      pu  presbyterian clergyman who was also president ...  1935.0
# 17     dlc                               by an american tory.  1936.0
# 18      wu                                by a union soldier.  1937.0
# 19     whi  methodist clergyman in kansas, nebraska, utah,...     0.0

# %% [markdown]
# ## Verify exact match works

# %%
compare_dataframes(gt_df, pred_df, "exact")
# Out:
# {'__COL__:lastname': np.int64(20),
#  '__COL__:firstname': np.int64(20),
#  '__COL__:maidenname': np.int64(20),
#  '__COL__:birthyear': np.int64(20),
#  '__COL__:deathyear': np.int64(20),
#  '__COL__:title': np.int64(20),
#  '__COL__:city': np.int64(20),
#  '__COL__:publisher': np.int64(20),
#  '__COL__:publishyear': np.int64(20),
#  '__COL__:pagecount': np.int64(20),
#  '__COL__:library': np.int64(20),
#  '__COL__:description': np.int64(20),
#  '__COL__:index': np.int64(20),
#  'matches': np.int64(260),
#  'total': 260,
#  'mismatch_bool': False,
#  'pred_nrows': 20,
#  'pred_adj_nrows': 20,
#  'gt_nrows': 20}

# %% [markdown]
# ### Verify that compare_dataframes does not modify dataframes

# %%
(gt_df == gt_df_original).count().sum()
# Out:
# np.int64(260)

# %% [markdown]
# ### Check more detailed results

# %%
detailed_results = compare_dataframes_core(gt_df, pred_df, "exact")

# %%
detailed_results["match_df"]
# Out:
#     lastname  firstname  maidenname  birthyear  deathyear  title  city  \
# 0       True       True        True       True       True   True  True
# 1       True       True        True       True       True   True  True
# 2       True       True        True       True       True   True  True
# 3       True       True        True       True       True   True  True
# 4       True       True        True       True       True   True  True
# 5       True       True        True       True       True   True  True
# 6       True       True        True       True       True   True  True
# 7       True       True        True       True       True   True  True
# 8       True       True        True       True       True   True  True
# 9       True       True        True       True       True   True  True
# 10      True       True        True       True       True   True  True
# 11      True       True        True       True       True   True  True
# 12      True       True        True       True       True   True  True
# 13      True       True        True       True       True   True  True
# 14      True       True        True       True       True   True  True
# 15      True       True        True       True       True   True  True
# 16      True       True        True       True       True   True  True
# 17      True       True        True       True       True   True  True
# 18      True       True        True       True       True   True  True
# 19      True       True        True       True       True   True  True
#
#     publisher  publishyear  pagecount  library  description  index
# 0        True         True       True     True         True   True
# 1        True         True       True     True         True   True
# 2        True         True       True     True         True   True
# 3        True         True       True     True         True   True
# 4        True         True       True     True         True   True
# 5        True         True       True     True         True   True
# 6        True         True       True     True         True   True
# 7        True         True       True     True         True   True
# 8        True         True       True     True         True   True
# 9        True         True       True     True         True   True
# 10       True         True       True     True         True   True
# 11       True         True       True     True         True   True
# 12       True         True       True     True         True   True
# 13       True         True       True     True         True   True
# 14       True         True       True     True         True   True
# 15       True         True       True     True         True   True
# 16       True         True       True     True         True   True
# 17       True         True       True     True         True   True
# 18       True         True       True     True         True   True
# 19       True         True       True     True         True   True

# %% [markdown]
# ## Ensure cell mismatches are handled properly

# %%
pred_df_cell_mismatch.head()
# Out:
#   lastname        firstname maidenname  birthyear  deathyear  \
# 0    field        joseph e.                   0.0        0.0
# 1    field          richard                1843.0        0.0
# 2    field  stephen johnson                1816.0     1899.0
# 3    fifer    joseph wilson                1840.0        0.0
# 4    finch       edwin ward                1831.0        0.0
#
#                                                title               city  \
# 0                            three years in texas...             boston
# 1                                     richard field.     lexington, mo.
# 2  personal reminiscences of early days in califo...     san francisco?
# 3      "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4  the frontier, army and professional life of ed...               n.y.
#
#                              publisher  publishyear  pagecount library  \
# 0                        abel tompkins       1836.0       47.0     dlc
# 1                                            1930.0       38.0     mok
# 2                                            1880.0      248.0     whi
# 3                   pantagraph pr. co.       9999.0      104.0     whi
# 4  press of simmonds, manning & dawson       1909.0      119.0     dlc
#
#                                          description   index
# 0            his experiences in the war with mexico.  1920.0
# 1  missouri lawyer and judge tells also of his yo...  1921.0
# 2                                     no description  1922.0
# 3         Civil War soldier and governor of Illinoi.  1923.0
# 4  a new york physician tells of his boyhood on a...  1924.0

# %%
detailed_results = compare_dataframes_core(gt_df, pred_df_cell_mismatch, "exact")
print(detailed_results["results"])
detailed_results["match_df"]
# Out:
# {'__COL__:lastname': np.int64(20), '__COL__:firstname': np.int64(20), '__COL__:maidenname': np.int64(20), '__COL__:birthyear': np.int64(20), '__COL__:deathyear': np.int64(20), '__COL__:title': np.int64(20), '__COL__:city': np.int64(20), '__COL__:publisher': np.int64(20), '__COL__:publishyear': np.int64(19), '__COL__:pagecount': np.int64(20), '__COL__:library': np.int64(20), '__COL__:description': np.int64(18), '__COL__:index': np.int64(20), 'matches': np.int64(257), 'total': 260, 'mismatch_bool': False, 'pred_nrows': 20, 'pred_adj_nrows': 20, 'gt_nrows': 20}
#     lastname  firstname  maidenname  birthyear  deathyear  title  city  \
# 0       True       True        True       True       True   True  True
# 1       True       True        True       True       True   True  True
# 2       True       True        True       True       True   True  True
# 3       True       True        True       True       True   True  True
# 4       True       True        True       True       True   True  True
# 5       True       True        True       True       True   True  True
# 6       True       True        True       True       True   True  True
# 7       True       True        True       True       True   True  True
# 8       True       True        True       True       True   True  True
# 9       True       True        True       True       True   True  True
# 10      True       True        True       True       True   True  True
# 11      True       True        True       True       True   True  True
# 12      True       True        True       True       True   True  True
# 13      True       True        True       True       True   True  True
# 14      True       True        True       True       True   True  True
# 15      True       True        True       True       True   True  True
# 16      True       True        True       True       True   True  True
# 17      True       True        True       True       True   True  True
# 18      True       True        True       True       True   True  True
# 19      True       True        True       True       True   True  True
#
#     publisher  publishyear  pagecount  library  description  index
# 0        True         True       True     True         True   True
# 1        True         True       True     True         True   True
# 2        True         True       True     True        False   True
# 3        True        False       True     True        False   True
# 4        True         True       True     True         True   True
# 5        True         True       True     True         True   True
# 6        True         True       True     True         True   True
# 7        True         True       True     True         True   True
# 8        True         True       True     True         True   True
# 9        True         True       True     True         True   True
# 10       True         True       True     True         True   True
# 11       True         True       True     True         True   True
# 12       True         True       True     True         True   True
# 13       True         True       True     True         True   True
# 14       True         True       True     True         True   True
# 15       True         True       True     True         True   True
# 16       True         True       True     True         True   True
# 17       True         True       True     True         True   True
# 18       True         True       True     True         True   True
# 19       True         True       True     True         True   True

# %%
# Should only have one False description instead of two
detailed_results = compare_dataframes_core(gt_df, pred_df_cell_mismatch, "fuzzy")
print(detailed_results["results"])
detailed_results["match_df"]
# Out:
# {'__COL__:lastname': np.int64(20), '__COL__:firstname': np.int64(20), '__COL__:maidenname': np.int64(20), '__COL__:birthyear': np.int64(20), '__COL__:deathyear': np.int64(20), '__COL__:title': np.int64(20), '__COL__:city': np.int64(20), '__COL__:publisher': np.int64(20), '__COL__:publishyear': np.int64(19), '__COL__:pagecount': np.int64(20), '__COL__:library': np.int64(20), '__COL__:description': np.int64(19), '__COL__:index': np.int64(20), 'matches': np.int64(258), 'total': 260, 'mismatch_bool': False, 'pred_nrows': 20, 'pred_adj_nrows': 20, 'gt_nrows': 20}
#     lastname  firstname  maidenname  birthyear  deathyear  title  city  \
# 0       True       True        True       True       True   True  True
# 1       True       True        True       True       True   True  True
# 2       True       True        True       True       True   True  True
# 3       True       True        True       True       True   True  True
# 4       True       True        True       True       True   True  True
# 5       True       True        True       True       True   True  True
# 6       True       True        True       True       True   True  True
# 7       True       True        True       True       True   True  True
# 8       True       True        True       True       True   True  True
# 9       True       True        True       True       True   True  True
# 10      True       True        True       True       True   True  True
# 11      True       True        True       True       True   True  True
# 12      True       True        True       True       True   True  True
# 13      True       True        True       True       True   True  True
# 14      True       True        True       True       True   True  True
# 15      True       True        True       True       True   True  True
# 16      True       True        True       True       True   True  True
# 17      True       True        True       True       True   True  True
# 18      True       True        True       True       True   True  True
# 19      True       True        True       True       True   True  True
#
#     publisher  publishyear  pagecount  library  description  index
# 0        True         True       True     True         True   True
# 1        True         True       True     True         True   True
# 2        True         True       True     True        False   True
# 3        True        False       True     True         True   True
# 4        True         True       True     True         True   True
# 5        True         True       True     True         True   True
# 6        True         True       True     True         True   True
# 7        True         True       True     True         True   True
# 8        True         True       True     True         True   True
# 9        True         True       True     True         True   True
# 10       True         True       True     True         True   True
# 11       True         True       True     True         True   True
# 12       True         True       True     True         True   True
# 13       True         True       True     True         True   True
# 14       True         True       True     True         True   True
# 15       True         True       True     True         True   True
# 16       True         True       True     True         True   True
# 17       True         True       True     True         True   True
# 18       True         True       True     True         True   True
# 19       True         True       True     True         True   True

# %% [markdown]
# ## Ensure top row mismatches are handled properly
# - Should add a row in the processed dataframe.

# %%
pred_df_top_row_mismatch.head()
# Out:
#   lastname         firstname maidenname  birthyear  deathyear  \
# 0    field           richard                1843.0        0.0
# 1    field   stephen johnson                1816.0     1899.0
# 2    fifer     joseph wilson                1840.0        0.0
# 3    finch        edwin ward                1831.0        0.0
# 4    finck  henry theophilos                1854.0     1926.0
#
#                                                title               city  \
# 0                                     richard field.     lexington, mo.
# 1  personal reminiscences of early days in califo...     san francisco?
# 2      "private joe" fifer. memories of war & peace.  bloomington, ill.
# 3  the frontier, army and professional life of ed...               n.y.
# 4          my adventures in the golden age of music.               n.y.
#
#                              publisher  publishyear  pagecount library  \
# 0                                            1930.0       38.0     mok
# 1                                            1880.0      248.0     whi
# 2                   pantagraph pr. co.       1936.0      104.0     whi
# 3  press of simmonds, manning & dawson       1909.0      119.0     dlc
# 4                      funk & wagnalls       1926.0      462.0      wu
#
#                                          description   index
# 0  missouri lawyer and judge tells also of his yo...  1921.0
# 1    by a judge and member of the state legislature.  1922.0
# 2        civil war soldier and governor of illinois.  1923.0
# 3  a new york physician tells of his boyhood on a...  1924.0
# 4                                      music critic.  1925.0

# %%
detailed_results = compare_dataframes_core(gt_df, pred_df_top_row_mismatch, "exact")
print(detailed_results["results"])
detailed_results["match_df"]
# Out:
# {'__COL__:lastname': np.int64(19), '__COL__:firstname': np.int64(19), '__COL__:maidenname': np.int64(20), '__COL__:birthyear': np.int64(20), '__COL__:deathyear': np.int64(20), '__COL__:title': np.int64(19), '__COL__:city': np.int64(19), '__COL__:publisher': np.int64(19), '__COL__:publishyear': np.int64(19), '__COL__:pagecount': np.int64(19), '__COL__:library': np.int64(19), '__COL__:description': np.int64(19), '__COL__:index': np.int64(19), 'matches': np.int64(250), 'total': 260, 'mismatch_bool': False, 'pred_nrows': 19, 'pred_adj_nrows': 20, 'gt_nrows': 20}
#     lastname  firstname  maidenname  birthyear  deathyear  title   city  \
# 0      False      False        True       True       True  False  False
# 1       True       True        True       True       True   True   True
# 2       True       True        True       True       True   True   True
# 3       True       True        True       True       True   True   True
# 4       True       True        True       True       True   True   True
# 5       True       True        True       True       True   True   True
# 6       True       True        True       True       True   True   True
# 7       True       True        True       True       True   True   True
# 8       True       True        True       True       True   True   True
# 9       True       True        True       True       True   True   True
# 10      True       True        True       True       True   True   True
# 11      True       True        True       True       True   True   True
# 12      True       True        True       True       True   True   True
# 13      True       True        True       True       True   True   True
# 14      True       True        True       True       True   True   True
# 15      True       True        True       True       True   True   True
# 16      True       True        True       True       True   True   True
# 17      True       True        True       True       True   True   True
# 18      True       True        True       True       True   True   True
# 19      True       True        True       True       True   True   True
#
#     publisher  publishyear  pagecount  library  description  index
# 0       False        False      False    False        False  False
# 1        True         True       True     True         True   True
# 2        True         True       True     True         True   True
# 3        True         True       True     True         True   True
# 4        True         True       True     True         True   True
# 5        True         True       True     True         True   True
# 6        True         True       True     True         True   True
# 7        True         True       True     True         True   True
# 8        True         True       True     True         True   True
# 9        True         True       True     True         True   True
# 10       True         True       True     True         True   True
# 11       True         True       True     True         True   True
# 12       True         True       True     True         True   True
# 13       True         True       True     True         True   True
# 14       True         True       True     True         True   True
# 15       True         True       True     True         True   True
# 16       True         True       True     True         True   True
# 17       True         True       True     True         True   True
# 18       True         True       True     True         True   True
# 19       True         True       True     True         True   True

# %% [markdown]
# Note that above, the maiden name, birth year, and death year are empty in the original, so the top row is True for these three columns only and False otherwise.

# %%
detailed_results["pred_df_adj"]
# Out:
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0                                                   0.0        0.0
# 1       field             richard                1843.0        0.0
# 2       field     stephen johnson                1816.0     1899.0
# 3       fifer       joseph wilson                1840.0        0.0
# 4       finch          edwin ward                1831.0        0.0
# 5       finck    henry theophilos                1854.0     1926.0
# 6     finerty      john frederick                1846.0     1908.0
# 7      finley       james bradley                1781.0     1856.0
# 8      finley       james bradley                1781.0     1856.0
# 9        finn       francis james                1859.0     1928.0
# 10     finney   charles grandison                1792.0     1875.0
# 11     finney   charles grandison                   0.0     1875.0
# 12     finney  john miller turpin                1863.0        0.0
# 13  firestone           harvey s.                   0.0        0.0
# 14    fischer   augusta catherine                1891.0        0.0
# 15     fisher               clara                   0.0        0.0
# 16     fisher      daniel webster                1838.0     1913.0
# 17     fisher           elizabeth      munro     1759.0        0.0
# 18     fisher        george adams                1835.0        0.0
# 19     fisher           hugh dunn                1824.0        0.0
#
#                                                 title               city  \
# 0
# 1                                      richard field.     lexington, mo.
# 2   personal reminiscences of early days in califo...     san francisco?
# 3       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4   the frontier, army and professional life of ed...               n.y.
# 5           my adventures in the golden age of music.               n.y.
# 6   war-path and bivouac... the big horn and yello...            chicago
# 7   autobiography of rev. james b. finley; or, pio...              cinc.
# 8                           life among the indians...              cinc.
# 9   father finn, s.j.; the story of his life told ...               n.y.
# 10   charles g. finney. an autobiography. popular ed.       london, n.y.
# 11                        the inner and outer life...             london
# 12                                  a surgeon's life.               n.y.
# 13                                  men and rubber...        garden city
# 14                     searchlight; an autobiography.            seattle
# 15
# 16                                    a human life...               n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 18  the yankee conscript, or eighteen months in di...             phila.
# 19                   the gun and the gospel...4th ed.        kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                                              0.0        0.0
# 1                                                           1930.0       38.0
# 2                                                           1880.0      248.0
# 3                                  pantagraph pr. co.       1936.0      104.0
# 4                 press of simmonds, manning & dawson       1909.0      119.0
# 5                                     funk & wagnalls       1926.0      462.0
# 6                                                           1890.0      460.0
# 7   pr. at the methodist book concern, for the author       1853.0      455.0
# 8                                  hitchcock & walden       1868.0      507.0
# 9                                      benziger bros.       1929.0      236.0
# 10                 the slavation army book department       1903.0      401.0
# 11                                    s. w. partridge       1882.0       32.0
# 12                                             putnam       1940.0      400.0
# 13                                    doubleday, page       1926.0      279.0
# 14                                                          1937.0      233.0
# 15                                                             0.0        0.0
# 16                                             revell       1909.0      325.0
# 17                                                          1810.0       48.0
# 18                                    j. w. daughaday       1864.0      251.0
# 19                                    hudson-kimberly       1902.0      347.0
#
#    library                                        description   index
# 0                                                                 0.0
# 1      mok  missouri lawyer and judge tells also of his yo...  1921.0
# 2      whi    by a judge and member of the state legislature.  1922.0
# 3      whi        civil war soldier and governor of illinois.  1923.0
# 4      dlc  a new york physician tells of his boyhood on a...  1924.0
# 5       wu                                      music critic.  1925.0
# 6      dlc  newspaper correspondent with crook, 1866-67, i...  1926.0
# 7      whi                    methodist in the old northwest.  1927.0
# 8      whi          an enlarged version of the previous item.  1928.0
# 9       nn  teacher in st. louis and cincinnati. a pioneer...  1929.0
# 10     whi  presbyterian, later congregational, clergyman ...  1930.0
# 11     whi  the author left the presbyterian church to bec...  1931.0
# 12      wu                     in massachusetts and maryland.  1932.0
# 13      wu                   manufacturer of rubber products.  1933.0
# 14      nn  the story of the causes leading to the author'...  1934.0
# 15                           see maeder, mrs. clara (fisher).     0.0
# 16      pu  presbyterian clergyman who was also president ...  1935.0
# 17     dlc                               by an american tory.  1936.0
# 18      wu                                by a union soldier.  1937.0
# 19     whi  methodist clergyman in kansas, nebraska, utah,...     0.0

# %% [markdown]
# The modified top row is completely empty with the correct default values.

# %% [markdown]
# ## Ensure bottom row mismatches are handled properly

# %%
pred_df_bottom_row_mismatch.tail()
# Out:
#    lastname          firstname maidenname  birthyear  deathyear  \
# 14  fischer  augusta catherine                1891.0        0.0
# 15   fisher              clara                   0.0        0.0
# 16   fisher     daniel webster                1838.0     1913.0
# 17   fisher          elizabeth      munro     1759.0        0.0
# 18   fisher       george adams                1835.0        0.0
#
#                                                 title     city  \
# 14                     searchlight; an autobiography.  seattle
# 15
# 16                                    a human life...     n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...     n.y.
# 18  the yankee conscript, or eighteen months in di...   phila.
#
#           publisher  publishyear  pagecount library  \
# 14                        1937.0      233.0      nn
# 15                           0.0        0.0
# 16           revell       1909.0      325.0      pu
# 17                        1810.0       48.0     dlc
# 18  j. w. daughaday       1864.0      251.0      wu
#
#                                           description   index
# 14  the story of the causes leading to the author'...  1934.0
# 15                   see maeder, mrs. clara (fisher).     0.0
# 16  presbyterian clergyman who was also president ...  1935.0
# 17                               by an american tory.  1936.0
# 18                                by a union soldier.  1937.0

# %%
detailed_results = compare_dataframes_core(gt_df, pred_df_bottom_row_mismatch, "exact")
print(detailed_results["results"])
detailed_results["match_df"]
# Out:
# {'__COL__:lastname': np.int64(9), '__COL__:firstname': np.int64(2), '__COL__:maidenname': np.int64(18), '__COL__:birthyear': np.int64(2), '__COL__:deathyear': np.int64(10), '__COL__:title': np.int64(0), '__COL__:city': np.int64(3), '__COL__:publisher': np.int64(2), '__COL__:publishyear': np.int64(0), '__COL__:pagecount': np.int64(0), '__COL__:library': np.int64(4), '__COL__:description': np.int64(0), '__COL__:index': np.int64(0), 'matches': np.int64(50), 'total': 260, 'mismatch_bool': False, 'pred_nrows': 19, 'pred_adj_nrows': 20, 'gt_nrows': 20}
#     lastname  firstname  maidenname  birthyear  deathyear  title   city  \
# 0      False      False        True       True       True  False  False
# 1       True      False        True      False       True  False  False
# 2       True      False        True      False      False  False  False
# 3      False      False        True      False      False  False  False
# 4      False      False        True      False       True  False  False
# 5      False      False        True      False      False  False   True
# 6      False      False        True      False      False  False  False
# 7      False      False        True      False      False  False  False
# 8       True       True        True       True       True  False   True
# 9      False      False        True      False      False  False  False
# 10     False      False        True      False      False  False  False
# 11      True       True        True      False       True  False  False
# 12      True      False        True      False      False  False  False
# 13     False      False        True      False       True  False  False
# 14     False      False        True      False       True  False  False
# 15     False      False        True      False       True  False  False
# 16      True      False        True      False      False  False  False
# 17      True      False       False      False      False  False   True
# 18      True      False       False      False       True  False  False
# 19      True      False        True      False       True  False  False
#
#     publisher  publishyear  pagecount  library  description  index
# 0       False        False      False    False        False  False
# 1       False        False      False    False        False  False
# 2        True        False      False    False        False  False
# 3       False        False      False     True        False  False
# 4       False        False      False    False        False  False
# 5       False        False      False    False        False  False
# 6       False        False      False    False        False  False
# 7       False        False      False    False        False  False
# 8       False        False      False     True        False  False
# 9       False        False      False    False        False  False
# 10      False        False      False    False        False  False
# 11      False        False      False     True        False  False
# 12      False        False      False    False        False  False
# 13      False        False      False     True        False  False
# 14      False        False      False    False        False  False
# 15       True        False      False    False        False  False
# 16      False        False      False    False        False  False
# 17      False        False      False    False        False  False
# 18      False        False      False    False        False  False
# 19      False        False      False    False        False  False

# %%
detailed_results["pred_df_adj"]
# Out:
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0                                                   0.0        0.0
# 1       field           joseph e.                   0.0        0.0
# 2       field             richard                1843.0        0.0
# 3       field     stephen johnson                1816.0     1899.0
# 4       fifer       joseph wilson                1840.0        0.0
# 5       finch          edwin ward                1831.0        0.0
# 6       finck    henry theophilos                1854.0     1926.0
# 7     finerty      john frederick                1846.0     1908.0
# 8      finley       james bradley                1781.0     1856.0
# 9      finley       james bradley                1781.0     1856.0
# 10       finn       francis james                1859.0     1928.0
# 11     finney   charles grandison                1792.0     1875.0
# 12     finney   charles grandison                   0.0     1875.0
# 13     finney  john miller turpin                1863.0        0.0
# 14  firestone           harvey s.                   0.0        0.0
# 15    fischer   augusta catherine                1891.0        0.0
# 16     fisher               clara                   0.0        0.0
# 17     fisher      daniel webster                1838.0     1913.0
# 18     fisher           elizabeth      munro     1759.0        0.0
# 19     fisher        george adams                1835.0        0.0
#
#                                                 title               city  \
# 0
# 1                             three years in texas...             boston
# 2                                      richard field.     lexington, mo.
# 3   personal reminiscences of early days in califo...     san francisco?
# 4       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 5   the frontier, army and professional life of ed...               n.y.
# 6           my adventures in the golden age of music.               n.y.
# 7   war-path and bivouac... the big horn and yello...            chicago
# 8   autobiography of rev. james b. finley; or, pio...              cinc.
# 9                           life among the indians...              cinc.
# 10  father finn, s.j.; the story of his life told ...               n.y.
# 11   charles g. finney. an autobiography. popular ed.       london, n.y.
# 12                        the inner and outer life...             london
# 13                                  a surgeon's life.               n.y.
# 14                                  men and rubber...        garden city
# 15                     searchlight; an autobiography.            seattle
# 16
# 17                                    a human life...               n.y.
# 18  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 19  the yankee conscript, or eighteen months in di...             phila.
#
#                                             publisher  publishyear  pagecount  \
# 0                                                              0.0        0.0
# 1                                       abel tompkins       1836.0       47.0
# 2                                                           1930.0       38.0
# 3                                                           1880.0      248.0
# 4                                  pantagraph pr. co.       1936.0      104.0
# 5                 press of simmonds, manning & dawson       1909.0      119.0
# 6                                     funk & wagnalls       1926.0      462.0
# 7                                                           1890.0      460.0
# 8   pr. at the methodist book concern, for the author       1853.0      455.0
# 9                                  hitchcock & walden       1868.0      507.0
# 10                                     benziger bros.       1929.0      236.0
# 11                 the slavation army book department       1903.0      401.0
# 12                                    s. w. partridge       1882.0       32.0
# 13                                             putnam       1940.0      400.0
# 14                                    doubleday, page       1926.0      279.0
# 15                                                          1937.0      233.0
# 16                                                             0.0        0.0
# 17                                             revell       1909.0      325.0
# 18                                                          1810.0       48.0
# 19                                    j. w. daughaday       1864.0      251.0
#
#    library                                        description   index
# 0                                                                 0.0
# 1      dlc            his experiences in the war with mexico.  1920.0
# 2      mok  missouri lawyer and judge tells also of his yo...  1921.0
# 3      whi    by a judge and member of the state legislature.  1922.0
# 4      whi        civil war soldier and governor of illinois.  1923.0
# 5      dlc  a new york physician tells of his boyhood on a...  1924.0
# 6       wu                                      music critic.  1925.0
# 7      dlc  newspaper correspondent with crook, 1866-67, i...  1926.0
# 8      whi                    methodist in the old northwest.  1927.0
# 9      whi          an enlarged version of the previous item.  1928.0
# 10      nn  teacher in st. louis and cincinnati. a pioneer...  1929.0
# 11     whi  presbyterian, later congregational, clergyman ...  1930.0
# 12     whi  the author left the presbyterian church to bec...  1931.0
# 13      wu                     in massachusetts and maryland.  1932.0
# 14      wu                   manufacturer of rubber products.  1933.0
# 15      nn  the story of the causes leading to the author'...  1934.0
# 16                           see maeder, mrs. clara (fisher).     0.0
# 17      pu  presbyterian clergyman who was also president ...  1935.0
# 18     dlc                               by an american tory.  1936.0
# 19      wu                                by a union soldier.  1937.0

# %% [markdown]
# This solution causes row misalignment, so the behavior of many rows being false is expected.
#
# The only exception is repeating rows (i.e. last name) or sparse rows (i.e. missing names).

# %% [markdown]
# ## Ensure mismatches of more than 1 row are not compared

# %%
pred_df_two_rows_mismatch.head()
# Out:
#   lastname         firstname maidenname  birthyear  deathyear  \
# 0    field   stephen johnson                1816.0     1899.0
# 1    fifer     joseph wilson                1840.0        0.0
# 2    finch        edwin ward                1831.0        0.0
# 3    finck  henry theophilos                1854.0     1926.0
# 4  finerty    john frederick                1846.0     1908.0
#
#                                                title               city  \
# 0  personal reminiscences of early days in califo...     san francisco?
# 1      "private joe" fifer. memories of war & peace.  bloomington, ill.
# 2  the frontier, army and professional life of ed...               n.y.
# 3          my adventures in the golden age of music.               n.y.
# 4  war-path and bivouac... the big horn and yello...            chicago
#
#                              publisher  publishyear  pagecount library  \
# 0                                            1880.0      248.0     whi
# 1                   pantagraph pr. co.       1936.0      104.0     whi
# 2  press of simmonds, manning & dawson       1909.0      119.0     dlc
# 3                      funk & wagnalls       1926.0      462.0      wu
# 4                                            1890.0      460.0     dlc
#
#                                          description   index
# 0    by a judge and member of the state legislature.  1922.0
# 1        civil war soldier and governor of illinois.  1923.0
# 2  a new york physician tells of his boyhood on a...  1924.0
# 3                                      music critic.  1925.0
# 4  newspaper correspondent with crook, 1866-67, i...  1926.0

# %%
detailed_results = compare_dataframes_core(gt_df, pred_df_two_rows_mismatch, "exact")
detailed_results["results"]
# Out:
# {'matches': nan,
#  'total': nan,
#  'mismatch_bool': True,
#  'pred_nrows': 18,
#  'pred_adj_nrows': 18,
#  'gt_nrows': 20}

# %% [markdown]
# ## Test how missing columns are handled

# %%
pred_df_removed_col
# Out:
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0       field           joseph e.                   0.0        0.0
# 1       field             richard                1843.0        0.0
# 2       field     stephen johnson                1816.0     1899.0
# 3       fifer       joseph wilson                1840.0        0.0
# 4       finch          edwin ward                1831.0        0.0
# 5       finck    henry theophilos                1854.0     1926.0
# 6     finerty      john frederick                1846.0     1908.0
# 7      finley       james bradley                1781.0     1856.0
# 8      finley       james bradley                1781.0     1856.0
# 9        finn       francis james                1859.0     1928.0
# 10     finney   charles grandison                1792.0     1875.0
# 11     finney   charles grandison                   0.0     1875.0
# 12     finney  john miller turpin                1863.0        0.0
# 13  firestone           harvey s.                   0.0        0.0
# 14    fischer   augusta catherine                1891.0        0.0
# 15     fisher               clara                   0.0        0.0
# 16     fisher      daniel webster                1838.0     1913.0
# 17     fisher           elizabeth      munro     1759.0        0.0
# 18     fisher        george adams                1835.0        0.0
# 19     fisher           hugh dunn                1824.0        0.0
#
#                                                 title               city  \
# 0                             three years in texas...             boston
# 1                                      richard field.     lexington, mo.
# 2   personal reminiscences of early days in califo...     san francisco?
# 3       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4   the frontier, army and professional life of ed...               n.y.
# 5           my adventures in the golden age of music.               n.y.
# 6   war-path and bivouac... the big horn and yello...            chicago
# 7   autobiography of rev. james b. finley; or, pio...              cinc.
# 8                           life among the indians...              cinc.
# 9   father finn, s.j.; the story of his life told ...               n.y.
# 10   charles g. finney. an autobiography. popular ed.       london, n.y.
# 11                        the inner and outer life...             london
# 12                                  a surgeon's life.               n.y.
# 13                                  men and rubber...        garden city
# 14                     searchlight; an autobiography.            seattle
# 15
# 16                                    a human life...               n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 18  the yankee conscript, or eighteen months in di...             phila.
# 19                   the gun and the gospel...4th ed.        kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                       abel tompkins       1836.0       47.0
# 1                                                           1930.0       38.0
# 2                                                           1880.0      248.0
# 3                                  pantagraph pr. co.       1936.0      104.0
# 4                 press of simmonds, manning & dawson       1909.0      119.0
# 5                                     funk & wagnalls       1926.0      462.0
# 6                                                           1890.0      460.0
# 7   pr. at the methodist book concern, for the author       1853.0      455.0
# 8                                  hitchcock & walden       1868.0      507.0
# 9                                      benziger bros.       1929.0      236.0
# 10                 the slavation army book department       1903.0      401.0
# 11                                    s. w. partridge       1882.0       32.0
# 12                                             putnam       1940.0      400.0
# 13                                    doubleday, page       1926.0      279.0
# 14                                                          1937.0      233.0
# 15                                                             0.0        0.0
# 16                                             revell       1909.0      325.0
# 17                                                          1810.0       48.0
# 18                                    j. w. daughaday       1864.0      251.0
# 19                                    hudson-kimberly       1902.0      347.0
#
#    library
# 0      dlc
# 1      mok
# 2      whi
# 3      whi
# 4      dlc
# 5       wu
# 6      dlc
# 7      whi
# 8      whi
# 9       nn
# 10     whi
# 11     whi
# 12      wu
# 13      wu
# 14      nn
# 15
# 16      pu
# 17     dlc
# 18      wu
# 19     whi

# %%
filter_expected_columns(pred_df_removed_col)
# Out:
# /Users/timyu/projects/GC-20C-Text-Lab/ocr-benchmarking/src/benchmarking/json_accuracy.py:100: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(EXPECTED_COLUMNS_DEFAULTS)
#      lastname           firstname maidenname  birthyear  deathyear  \
# 0       field           joseph e.                   0.0        0.0
# 1       field             richard                1843.0        0.0
# 2       field     stephen johnson                1816.0     1899.0
# 3       fifer       joseph wilson                1840.0        0.0
# 4       finch          edwin ward                1831.0        0.0
# 5       finck    henry theophilos                1854.0     1926.0
# 6     finerty      john frederick                1846.0     1908.0
# 7      finley       james bradley                1781.0     1856.0
# 8      finley       james bradley                1781.0     1856.0
# 9        finn       francis james                1859.0     1928.0
# 10     finney   charles grandison                1792.0     1875.0
# 11     finney   charles grandison                   0.0     1875.0
# 12     finney  john miller turpin                1863.0        0.0
# 13  firestone           harvey s.                   0.0        0.0
# 14    fischer   augusta catherine                1891.0        0.0
# 15     fisher               clara                   0.0        0.0
# 16     fisher      daniel webster                1838.0     1913.0
# 17     fisher           elizabeth      munro     1759.0        0.0
# 18     fisher        george adams                1835.0        0.0
# 19     fisher           hugh dunn                1824.0        0.0
#
#                                                 title               city  \
# 0                             three years in texas...             boston
# 1                                      richard field.     lexington, mo.
# 2   personal reminiscences of early days in califo...     san francisco?
# 3       "private joe" fifer. memories of war & peace.  bloomington, ill.
# 4   the frontier, army and professional life of ed...               n.y.
# 5           my adventures in the golden age of music.               n.y.
# 6   war-path and bivouac... the big horn and yello...            chicago
# 7   autobiography of rev. james b. finley; or, pio...              cinc.
# 8                           life among the indians...              cinc.
# 9   father finn, s.j.; the story of his life told ...               n.y.
# 10   charles g. finney. an autobiography. popular ed.       london, n.y.
# 11                        the inner and outer life...             london
# 12                                  a surgeon's life.               n.y.
# 13                                  men and rubber...        garden city
# 14                     searchlight; an autobiography.            seattle
# 15
# 16                                    a human life...               n.y.
# 17  memoirs, of mrs. elizabeth fisher, of the city...               n.y.
# 18  the yankee conscript, or eighteen months in di...             phila.
# 19                   the gun and the gospel...4th ed.        kansas city
#
#                                             publisher  publishyear  pagecount  \
# 0                                       abel tompkins       1836.0       47.0
# 1                                                           1930.0       38.0
# 2                                                           1880.0      248.0
# 3                                  pantagraph pr. co.       1936.0      104.0
# 4                 press of simmonds, manning & dawson       1909.0      119.0
# 5                                     funk & wagnalls       1926.0      462.0
# 6                                                           1890.0      460.0
# 7   pr. at the methodist book concern, for the author       1853.0      455.0
# 8                                  hitchcock & walden       1868.0      507.0
# 9                                      benziger bros.       1929.0      236.0
# 10                 the slavation army book department       1903.0      401.0
# 11                                    s. w. partridge       1882.0       32.0
# 12                                             putnam       1940.0      400.0
# 13                                    doubleday, page       1926.0      279.0
# 14                                                          1937.0      233.0
# 15                                                             0.0        0.0
# 16                                             revell       1909.0      325.0
# 17                                                          1810.0       48.0
# 18                                    j. w. daughaday       1864.0      251.0
# 19                                    hudson-kimberly       1902.0      347.0
#
#    library description  index
# 0      dlc                  0
# 1      mok                  0
# 2      whi                  0
# 3      whi                  0
# 4      dlc                  0
# 5       wu                  0
# 6      dlc                  0
# 7      whi                  0
# 8      whi                  0
# 9       nn                  0
# 10     whi                  0
# 11     whi                  0
# 12      wu                  0
# 13      wu                  0
# 14      nn                  0
# 15                          0
# 16      pu                  0
# 17     dlc                  0
# 18      wu                  0
# 19     whi                  0

# %% [markdown]
# The dropped columns should be filled back with default values, signifying that the code handles non-existent columns properly.
